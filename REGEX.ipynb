# %%
import os
import re

DocumentLine='''
********************************************************************************************************
\t\tDATE: 09/10/2020
\t\tConcept: An interactive page used for investigation by Mr.Shelock Holmes (Regular Expression)
\t\tProgrammer: R.Akhilandeshwari
\t\tPlatform: Jupyter Notebook
********************************************************************************************************
'''
print(DocumentLine,"\n")
print("\t\t\t\t\t INVESTIGATION DEPRATMENT \n\n\n")

#Login Details Method
Users={'DD1':'selc.oms','DD2':'ramu.ramu','D3':'Sailu@123','D4':'Kalpana#08'}
def Login():
  UID=input("Enter your ID\n")
  for keys in Users:
    if keys == UID:
      Password=input("Enter Password\n")
      if Users[keys]==Password:
        print('*'*80,"\n \t\t\t YOU HAVE LOGGED IN SUCCESSFULLY \t\t\t\n",'*'*80)
        Case()
      else:
        print('*'*80,"\n \t\t\t YOUR CREDENTIALS ARE WRONG. ENTER CORRECTLY \t\t\t\n",'*'*80)
        Login()

#Method Describing the Case detatils
def Case():
  print('*'*80,"\n \t\t\t YOU ARE IN THE CASE DETAILS SECTION \t\t\t\n",'*'*80)
  CID=input("\n\t\t\tEnter the Case ID which you wanted to refer\n")
  if CID == 'Ind323(F)':
    print('*'*80,"\n \t\t\t CASE TITLE: MR.KALMAN MURDER CASE \t\t\t\n",'*'*80)
    os.startfile(r'C:\Users\akhil\Desktop\P5\REPORT.docx')
  elif CID=='Ind846(C)':
    print('*'*80,"\n \t\t\t CASE TITLE: MR.RAMAN CIVIL CASE \t\t\t\n",'*'*80)
  elif CID=='Ind647(D)':
    print('*'*80,"\n \t\t\t CASE TITLE: MR.KALYANI DOMESTIC CASE \t\t\t\n",'*'*80)
  else:
    print('*'*80,"\n \t\t\t Enter the Correct Case ID \t\t\t\n",'*'*80)
    Case()
  return (0)

#Method describing the case details
def CaseDesc():
  s=[]
  print('*'*80,"\n \t\t\t THE CASE DETAILS IN TEXT FORMAT \t\t\t\n",'*'*80)
  file=open(r"C:\Users\akhil\Desktop\P5\FIR.txt",'r')
  print("\n\n\n",'*'*100)
  for line in file:
    print (line)
  x="True"
  while x=="True":
    print("\n\n\n\n\nEnter the suspicious elements\t")
    val=input("\t")
    s.insert(0,val)
    ch=input("\nIs there more elements???(Y/N)\t")
    if ch=='Y':
      continue
    elif ch=='N':
      break
    else:
      print("Enter Correct Value")
  print("\n\n\n",'*'*100)
  print("\nThe suspected words are\n")
    for x in s:
      print(x)
    
  print("To check whether the elements are in the given report:-")
  for line in file:
    for word in line.split():
      re.search('^A*e$',word)

#Main Funtion
Login()
ch=input("Would you like to proceed with the investigation(Y/N)\n")
if ch=='Y':
CaseDesc()
else:
print("\nHOPE, The details are clear. Thank You :-)")
